# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 625

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID="
   
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}{weather_api_key}&q={city}"
        
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_json = requests.get(city_url).json()
       
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = weather_json['coord']['lat']
        city_lng = weather_json['coord']['lon']
        city_max_temp = weather_json['main']['temp_max']
        city_humidity = weather_json['main']['humidity']
        city_clouds = weather_json['clouds']['all']
        city_wind = weather_json['wind']['speed']
        city_country = weather_json['sys']['country']
        city_date = weather_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print(e)
        #print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# 'coord'
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | leningradskiy
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | palabuhanratu
# 'coord'
# Processing Record 6 of Set 1 | taolanaro
# 'coord'
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | caluquembe
# Processing Record 9 of Set 1 | boa viagem
# Processing Record 10 of Set 1 | beringovskiy
# Processing Record 11 of Set 1 | cabo san lucas
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | tommot
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | codrington
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | neuquen
# Processing Record 20 of Set 1 | korla
# Processing Record 21 of Set 1 | marv dasht
# 'coord'
# Processing Record 22 of Set 1 | nanortalik
# Processing Record 23 of Set 1 | mattru
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | rozkishne
# Processing Record 28 of Set 1 | hay river
# Processing Record 29 of Set 1 | bonnyville
# Processing Record 30 of Set 1 | caravelas
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | taoudenni
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | faanui
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | richards bay
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | antofagasta
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | iralaya
# Processing Record 44 of Set 1 | luderitz
# Processing Record 45 of Set 1 | axim
# Processing Record 46 of Set 1 | bang saphan
# Processing Record 47 of Set 1 | belushya guba
# 'coord'
# Processing Record 48 of Set 1 | miri
# Processing Record 49 of Set 1 | sisimiut
# Processing Record 50 of Set 1 | namatanai
# Processing Record 0 of Set 2 | vila franca do campo
# Processing Record 1 of Set 2 | avera
# Processing Record 2 of Set 2 | kodinsk
# Processing Record 3 of Set 2 | coburg
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | amderma
# 'coord'
# Processing Record 6 of Set 2 | marcona
# 'coord'
# Processing Record 7 of Set 2 | ewa beach
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | nizhneyansk
# 'coord'
# Processing Record 11 of Set 2 | lavrentiya
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | barentsburg
# 'coord'
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | pisco
# Processing Record 16 of Set 2 | provideniya
# Processing Record 17 of Set 2 | hamilton
# Processing Record 18 of Set 2 | oyem
# Processing Record 19 of Set 2 | rolim de moura
# 'coord'
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | nileshwar
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | kampot
# Processing Record 25 of Set 2 | meyungs
# 'coord'
# Processing Record 26 of Set 2 | zhangjiakou
# Processing Record 27 of Set 2 | lakes entrance
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | marawi
# Processing Record 32 of Set 2 | oparino
# Processing Record 33 of Set 2 | kupang
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | beni mazar
# Processing Record 36 of Set 2 | komsomolskoye
# Processing Record 37 of Set 2 | aykhal
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | jalu
# Processing Record 40 of Set 2 | ajdabiya
# Processing Record 41 of Set 2 | khao yoi
# Processing Record 42 of Set 2 | wagar
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | byron bay
# Processing Record 46 of Set 2 | tiksi
# Processing Record 47 of Set 2 | svobodnyy
# Processing Record 48 of Set 2 | upington
# Processing Record 49 of Set 2 | port hawkesbury
# Processing Record 0 of Set 3 | tuatapere
# Processing Record 1 of Set 3 | labutta
# 'coord'
# Processing Record 2 of Set 3 | surt
# Processing Record 3 of Set 3 | los llanos de aridane
# Processing Record 4 of Set 3 | coihaique
# Processing Record 5 of Set 3 | fortuna
# Processing Record 6 of Set 3 | mnogovershinnyy
# Processing Record 7 of Set 3 | cagliari
# Processing Record 8 of Set 3 | itarema
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | mount isa
# Processing Record 11 of Set 3 | vanimo
# Processing Record 12 of Set 3 | kiama
# Processing Record 13 of Set 3 | ternate
# Processing Record 14 of Set 3 | paka
# Processing Record 15 of Set 3 | gashua
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | faya
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | hokitika
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | pecos
# Processing Record 24 of Set 3 | taburi
# 'coord'
# Processing Record 25 of Set 3 | saldanha
# Processing Record 26 of Set 3 | carutapera
# Processing Record 27 of Set 3 | bluff
# Processing Record 28 of Set 3 | ropczyce
# Processing Record 29 of Set 3 | sorland
# Processing Record 30 of Set 3 | gallup
# Processing Record 31 of Set 3 | sentyabrskiy
# 'coord'
# Processing Record 32 of Set 3 | pemangkat
# Processing Record 33 of Set 3 | northam
# Processing Record 34 of Set 3 | kudahuvadhoo
# Processing Record 35 of Set 3 | albury
# Processing Record 36 of Set 3 | margate
# Processing Record 37 of Set 3 | veraval
# Processing Record 38 of Set 3 | laredo
# Processing Record 39 of Set 3 | vazante
# Processing Record 40 of Set 3 | belmonte
# Processing Record 41 of Set 3 | ola
# Processing Record 42 of Set 3 | great falls
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | west bay
# Processing Record 45 of Set 3 | chumikan
# Processing Record 46 of Set 3 | magadi
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | chai badan
# Processing Record 49 of Set 3 | tongsa
# 'coord'
# Processing Record 0 of Set 4 | port blair
# Processing Record 1 of Set 4 | hermanus
# Processing Record 2 of Set 4 | angoche
# Processing Record 3 of Set 4 | attawapiskat
# 'coord'
# Processing Record 4 of Set 4 | andenes
# Processing Record 5 of Set 4 | portarlington
# Processing Record 6 of Set 4 | tikapur
# Processing Record 7 of Set 4 | mangan
# Processing Record 8 of Set 4 | khani
# Processing Record 9 of Set 4 | hami
# Processing Record 10 of Set 4 | cidreira
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | honningsvag
# Processing Record 13 of Set 4 | alta floresta
# Processing Record 14 of Set 4 | narrabri
# Processing Record 15 of Set 4 | kebemer
# 'coord'
# Processing Record 16 of Set 4 | tuktoyaktuk
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | tura
# Processing Record 19 of Set 4 | tartki
# 'coord'
# Processing Record 20 of Set 4 | rosetta
# Processing Record 21 of Set 4 | arraial do cabo
# Processing Record 22 of Set 4 | puerto escondido
# Processing Record 23 of Set 4 | malakal
# Processing Record 24 of Set 4 | muktsar
# Processing Record 25 of Set 4 | narsaq
# Processing Record 26 of Set 4 | lolua
# 'coord'
# Processing Record 27 of Set 4 | christchurch
# Processing Record 28 of Set 4 | belfast
# Processing Record 29 of Set 4 | san antonio
# Processing Record 30 of Set 4 | butaritari
# Processing Record 31 of Set 4 | saint george
# Processing Record 32 of Set 4 | vanavara
# Processing Record 33 of Set 4 | dunmore town
# Processing Record 34 of Set 4 | orlik
# Processing Record 35 of Set 4 | abu samrah
# Processing Record 36 of Set 4 | comodoro rivadavia
# Processing Record 37 of Set 4 | marshall
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | tilichiki
# Processing Record 40 of Set 4 | santa rosa
# Processing Record 41 of Set 4 | guane
# Processing Record 42 of Set 4 | ati
# Processing Record 43 of Set 4 | galiwinku
# 'coord'
# Processing Record 44 of Set 4 | venice
# Processing Record 45 of Set 4 | kailua
# Processing Record 46 of Set 4 | cravo norte
# Processing Record 47 of Set 4 | husavik
# Processing Record 48 of Set 4 | morozovsk
# Processing Record 49 of Set 4 | fairbanks
# Processing Record 0 of Set 5 | norman wells
# Processing Record 1 of Set 5 | yaguajay
# Processing Record 2 of Set 5 | berasia
# Processing Record 3 of Set 5 | biak
# Processing Record 4 of Set 5 | mahebourg
# Processing Record 5 of Set 5 | portland
# Processing Record 6 of Set 5 | dhidhdhoo
# Processing Record 7 of Set 5 | sachin
# Processing Record 8 of Set 5 | bathsheba
# Processing Record 9 of Set 5 | salalah
# Processing Record 10 of Set 5 | pedro ii
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | saint-pierre
# Processing Record 13 of Set 5 | necochea
# Processing Record 14 of Set 5 | rawson
# Processing Record 15 of Set 5 | saint-augustin
# Processing Record 16 of Set 5 | flin flon
# Processing Record 17 of Set 5 | phan thiet
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | port alfred
# Processing Record 20 of Set 5 | hasaki
# Processing Record 21 of Set 5 | isiro
# Processing Record 22 of Set 5 | sulurpeta
# 'coord'
# Processing Record 23 of Set 5 | atambua
# Processing Record 24 of Set 5 | itaperuna
# Processing Record 25 of Set 5 | severnyy
# Processing Record 26 of Set 5 | san jeronimo
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | balkhash
# Processing Record 29 of Set 5 | humaita
# Processing Record 30 of Set 5 | barcelos
# Processing Record 31 of Set 5 | vila velha
# Processing Record 32 of Set 5 | tsihombe
# 'coord'
# Processing Record 33 of Set 5 | grand river south east
# 'coord'
# Processing Record 34 of Set 5 | yulara
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | avarua
# Processing Record 37 of Set 5 | ranong
# Processing Record 38 of Set 5 | lira
# Processing Record 39 of Set 5 | srednekolymsk
# Processing Record 40 of Set 5 | broome
# Processing Record 41 of Set 5 | north bend
# Processing Record 42 of Set 5 | aklavik
# Processing Record 43 of Set 5 | nenjiang
# Processing Record 44 of Set 5 | sitka
# Processing Record 45 of Set 5 | khandyga
# Processing Record 46 of Set 5 | rosarito
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | saint-georges
# Processing Record 0 of Set 6 | kaitangata
# Processing Record 1 of Set 6 | lompoc
# Processing Record 2 of Set 6 | arman
# Processing Record 3 of Set 6 | huarmey
# Processing Record 4 of Set 6 | priekule
# Processing Record 5 of Set 6 | sabang
# Processing Record 6 of Set 6 | karsun
# Processing Record 7 of Set 6 | coquimbo
# Processing Record 8 of Set 6 | ust-uda
# Processing Record 9 of Set 6 | awjilah
# Processing Record 10 of Set 6 | roma
# Processing Record 11 of Set 6 | xichang
# Processing Record 12 of Set 6 | manyoni
# Processing Record 13 of Set 6 | turka
# Processing Record 14 of Set 6 | potam
# Processing Record 15 of Set 6 | palmer
# Processing Record 16 of Set 6 | iqaluit
# Processing Record 17 of Set 6 | kawalu
# Processing Record 18 of Set 6 | jizan
# Processing Record 19 of Set 6 | ekimchan
# Processing Record 20 of Set 6 | klaksvik
# Processing Record 21 of Set 6 | itacarambi
# Processing Record 22 of Set 6 | itea
# Processing Record 23 of Set 6 | palaikastron
# Processing Record 24 of Set 6 | yerbogachen
# Processing Record 25 of Set 6 | warqla
# 'coord'
# Processing Record 26 of Set 6 | pimentel
# Processing Record 27 of Set 6 | mys shmidta
# 'coord'
# Processing Record 28 of Set 6 | katiola
# Processing Record 29 of Set 6 | svarstad
# Processing Record 30 of Set 6 | buraydah
# Processing Record 31 of Set 6 | namibe
# Processing Record 32 of Set 6 | high level
# Processing Record 33 of Set 6 | angers
# Processing Record 34 of Set 6 | college
# Processing Record 35 of Set 6 | sinnamary
# Processing Record 36 of Set 6 | laiagam
# 'coord'
# Processing Record 37 of Set 6 | magdagachi
# Processing Record 38 of Set 6 | chokurdakh
# Processing Record 39 of Set 6 | taseyevo
# Processing Record 40 of Set 6 | sur
# Processing Record 41 of Set 6 | goure
# Processing Record 42 of Set 6 | carballo
# Processing Record 43 of Set 6 | suicheng
# Processing Record 44 of Set 6 | fereydun kenar
# Processing Record 45 of Set 6 | khasan
# Processing Record 46 of Set 6 | conceicao do araguaia
# Processing Record 47 of Set 6 | nagar karnul
# Processing Record 48 of Set 6 | havre-saint-pierre
# Processing Record 49 of Set 6 | truth or consequences
# Processing Record 0 of Set 7 | willowmore
# Processing Record 1 of Set 7 | englewood
# Processing Record 2 of Set 7 | altay
# Processing Record 3 of Set 7 | jos
# Processing Record 4 of Set 7 | broken hill
# Processing Record 5 of Set 7 | malartic
# Processing Record 6 of Set 7 | nizhniy kuranakh
# Processing Record 7 of Set 7 | walvis bay
# Processing Record 8 of Set 7 | inyonga
# Processing Record 9 of Set 7 | buala
# Processing Record 10 of Set 7 | mbala
# Processing Record 11 of Set 7 | teya
# Processing Record 12 of Set 7 | grand-santi
# Processing Record 13 of Set 7 | coahuayana
# Processing Record 14 of Set 7 | bibiani
# Processing Record 15 of Set 7 | nara
# Processing Record 16 of Set 7 | port macquarie
# Processing Record 17 of Set 7 | pathein
# Processing Record 18 of Set 7 | hwange
# Processing Record 19 of Set 7 | prince rupert
# Processing Record 20 of Set 7 | astipalaia
# 'coord'
# Processing Record 21 of Set 7 | daokou
# Processing Record 22 of Set 7 | otjiwarongo
# Processing Record 23 of Set 7 | hervey bay
# Processing Record 24 of Set 7 | beloha
# Processing Record 25 of Set 7 | gat
# Processing Record 26 of Set 7 | paris
# Processing Record 27 of Set 7 | brusque
# Processing Record 28 of Set 7 | arrecife
# Processing Record 29 of Set 7 | tabiauea
# 'coord'
# Processing Record 30 of Set 7 | vao
# Processing Record 31 of Set 7 | japura
# Processing Record 32 of Set 7 | bontang
# Processing Record 33 of Set 7 | nova russas
# Processing Record 34 of Set 7 | te anau
# Processing Record 35 of Set 7 | sibolga
# Processing Record 36 of Set 7 | lao cai
# Processing Record 37 of Set 7 | maragogi
# Processing Record 38 of Set 7 | bur gabo
# 'coord'
# Processing Record 39 of Set 7 | zaltan
# Processing Record 40 of Set 7 | kasongo-lunda
# Processing Record 41 of Set 7 | lasa
# Processing Record 42 of Set 7 | launceston
# Processing Record 43 of Set 7 | pevek
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | orzinuovi
# Processing Record 46 of Set 7 | alugan
# Processing Record 47 of Set 7 | mpika
# Processing Record 48 of Set 7 | wulanhaote
# 'coord'
# Processing Record 49 of Set 7 | mangrol
# Processing Record 0 of Set 8 | bac lieu
# Processing Record 1 of Set 8 | marsa matruh
# Processing Record 2 of Set 8 | kahului
# Processing Record 3 of Set 8 | fiche
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 | sataua
# 'coord'
# Processing Record 6 of Set 8 | rorvik
# Processing Record 7 of Set 8 | sungai siput utara
# 'coord'
# Processing Record 8 of Set 8 | peddapuram
# Processing Record 9 of Set 8 | talnakh
# Processing Record 10 of Set 8 | kieta
# Processing Record 11 of Set 8 | asau
# Processing Record 12 of Set 8 | tarnow
# Processing Record 13 of Set 8 | ambilobe
# Processing Record 14 of Set 8 | half moon bay
# Processing Record 15 of Set 8 | sorvag
# 'coord'
# Processing Record 16 of Set 8 | nguiu
# 'coord'
# Processing Record 17 of Set 8 | tual
# Processing Record 18 of Set 8 | conneaut
# Processing Record 19 of Set 8 | ahipara
# Processing Record 20 of Set 8 | grand gaube
# Processing Record 21 of Set 8 | gombong
# Processing Record 22 of Set 8 | tautira
# Processing Record 23 of Set 8 | samarai
# Processing Record 24 of Set 8 | samusu
# 'coord'
# Processing Record 25 of Set 8 | tam ky
# Processing Record 26 of Set 8 | matara
# Processing Record 27 of Set 8 | zaporizhzhya
# Processing Record 28 of Set 8 | tucuma
# Processing Record 29 of Set 8 | barsovo
# Processing Record 30 of Set 8 | komsomolskiy
# Processing Record 31 of Set 8 | rio gallegos
# Processing Record 32 of Set 8 | lichinga
# Processing Record 33 of Set 8 | bajo baudo
# 'coord'
# Processing Record 34 of Set 8 | maroantsetra
# Processing Record 35 of Set 8 | deputatskiy
# Processing Record 36 of Set 8 | luanda
# Processing Record 37 of Set 8 | ochamchira
# Processing Record 38 of Set 8 | chebsara
# Processing Record 39 of Set 8 | okhotsk
# Processing Record 40 of Set 8 | mumford
# Processing Record 41 of Set 8 | villa maria
# Processing Record 42 of Set 8 | agadez
# Processing Record 43 of Set 8 | herend
# Processing Record 44 of Set 8 | louisbourg
# 'coord'
# Processing Record 45 of Set 8 | kaohsiung
# Processing Record 46 of Set 8 | aflu
# 'coord'
# Processing Record 47 of Set 8 | sola
# Processing Record 48 of Set 8 | mar del plata
# Processing Record 49 of Set 8 | yaan
# Processing Record 0 of Set 9 | satipo
# Processing Record 1 of Set 9 | geraldton
# Processing Record 2 of Set 9 | zhangye
# Processing Record 3 of Set 9 | longyearbyen
# Processing Record 4 of Set 9 | wharton
# Processing Record 5 of Set 9 | laguna
# Processing Record 6 of Set 9 | ostersund
# Processing Record 7 of Set 9 | okato
# Processing Record 8 of Set 9 | aguimes
# Processing Record 9 of Set 9 | catuday
# Processing Record 10 of Set 9 | lata
# Processing Record 11 of Set 9 | smirnykh
# Processing Record 12 of Set 9 | mahanje
# Processing Record 13 of Set 9 | imperia
# Processing Record 14 of Set 9 | kalmunai
# Processing Record 15 of Set 9 | san jose
# Processing Record 16 of Set 9 | lorengau
# Processing Record 17 of Set 9 | litoral del san juan
# 'coord'
# Processing Record 18 of Set 9 | cordoba
# Processing Record 19 of Set 9 | durango
# Processing Record 20 of Set 9 | clyde river
# Processing Record 21 of Set 9 | bandarbeyla
# Processing Record 22 of Set 9 | yamada
# Processing Record 23 of Set 9 | bajram curri
# Processing Record 24 of Set 9 | balimo
# 'coord'
# Processing Record 25 of Set 9 | havoysund
# Processing Record 26 of Set 9 | lengshuitan
# Processing Record 27 of Set 9 | leshukonskoye
# Processing Record 28 of Set 9 | mersing
# Processing Record 29 of Set 9 | rundu
# Processing Record 30 of Set 9 | pacific grove
# Processing Record 31 of Set 9 | noshiro
# Processing Record 32 of Set 9 | aksarka
# Processing Record 33 of Set 9 | the valley
# Processing Record 34 of Set 9 | darnah
# Processing Record 35 of Set 9 | yinchuan
# Processing Record 36 of Set 9 | khanpur
# Processing Record 37 of Set 9 | bollnas
# Processing Record 38 of Set 9 | oussouye
# Processing Record 39 of Set 9 | sangar
# Processing Record 40 of Set 9 | garden city
# Processing Record 41 of Set 9 | banjar
# Processing Record 42 of Set 9 | stornoway
# Processing Record 43 of Set 9 | pacifica
# Processing Record 44 of Set 9 | calabozo
# Processing Record 45 of Set 9 | north augusta
# Processing Record 46 of Set 9 | requena
# Processing Record 47 of Set 9 | ostrovnoy
# Processing Record 48 of Set 9 | imeni poliny osipenko
# Processing Record 49 of Set 9 | bogorodskoye
# Processing Record 0 of Set 10 | constitucion
# Processing Record 1 of Set 10 | tsumeb
# Processing Record 2 of Set 10 | tahta
# Processing Record 3 of Set 10 | hammerfest
# Processing Record 4 of Set 10 | tumannyy
# 'coord'
# Processing Record 5 of Set 10 | san rafael
# Processing Record 6 of Set 10 | tabuk
# Processing Record 7 of Set 10 | sakakah
# Processing Record 8 of Set 10 | gizo
# Processing Record 9 of Set 10 | gazojak
# Processing Record 10 of Set 10 | imbituba
# Processing Record 11 of Set 10 | osuna
# Processing Record 12 of Set 10 | dingle
# Processing Record 13 of Set 10 | pringsewu
# Processing Record 14 of Set 10 | katsiveli
# 'coord'
# Processing Record 15 of Set 10 | ust-omchug
# Processing Record 16 of Set 10 | jieshi
# Processing Record 17 of Set 10 | cap malheureux
# Processing Record 18 of Set 10 | skoghall
# Processing Record 19 of Set 10 | novopavlovka
# Processing Record 20 of Set 10 | manggar
# Processing Record 21 of Set 10 | mayo
# Processing Record 22 of Set 10 | sao desiderio
# Processing Record 23 of Set 10 | rawannawi
# 'coord'
# Processing Record 24 of Set 10 | jiaocheng
# Processing Record 25 of Set 10 | samalaeulu
# 'coord'
# Processing Record 26 of Set 10 | muzhi
# Processing Record 27 of Set 10 | edd
# Processing Record 28 of Set 10 | fenoarivo atsinanana
# Processing Record 29 of Set 10 | goderich
# Processing Record 30 of Set 10 | katsuura
# Processing Record 31 of Set 10 | yumen
# Processing Record 32 of Set 10 | pandan niog
# Processing Record 33 of Set 10 | port lincoln
# Processing Record 34 of Set 10 | uvinza
# Processing Record 35 of Set 10 | ambalema
# Processing Record 36 of Set 10 | marsabit
# Processing Record 37 of Set 10 | pombia
# Processing Record 38 of Set 10 | waipawa
# Processing Record 39 of Set 10 | wanning
# Processing Record 40 of Set 10 | vaitupu
# 'coord'
# Processing Record 41 of Set 10 | curup
# Processing Record 42 of Set 10 | camacha
# Processing Record 43 of Set 10 | victoria
# Processing Record 44 of Set 10 | pahrump
# Processing Record 45 of Set 10 | isangel
# Processing Record 46 of Set 10 | saleaula
# 'coord'
# Processing Record 47 of Set 10 | bilma
# Processing Record 48 of Set 10 | kabalo
# Processing Record 49 of Set 10 | gualeguay
# Processing Record 0 of Set 11 | sao sebastiao
# Processing Record 1 of Set 11 | campo formoso
# Processing Record 2 of Set 11 | hualmay
# Processing Record 3 of Set 11 | chapais
# Processing Record 4 of Set 11 | aksu
# Processing Record 5 of Set 11 | bonavista
# Processing Record 6 of Set 11 | port maria
# Processing Record 7 of Set 11 | sao felix do xingu
# Processing Record 8 of Set 11 | kushikino
# Processing Record 9 of Set 11 | dondo
# Processing Record 10 of Set 11 | teshie
# Processing Record 11 of Set 11 | pangnirtung
# Processing Record 12 of Set 11 | itaqui
# Processing Record 13 of Set 11 | antalaha
# Processing Record 14 of Set 11 | tofield
# Processing Record 15 of Set 11 | yar-sale
# Processing Record 16 of Set 11 | moreira
# Processing Record 17 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 11 | liepaja
# Processing Record 19 of Set 11 | poum
# Processing Record 20 of Set 11 | nizhnyaya omka
# Processing Record 21 of Set 11 | juneau
# Processing Record 22 of Set 11 | sorong
# Processing Record 23 of Set 11 | lagoa
# Processing Record 24 of Set 11 | mehamn
# Processing Record 25 of Set 11 | alta
# Processing Record 26 of Set 11 | monrovia
# Processing Record 27 of Set 11 | san martin
# Processing Record 28 of Set 11 | angoram
# Processing Record 29 of Set 11 | rudnogorsk
# Processing Record 30 of Set 11 | castelu
# Processing Record 31 of Set 11 | formoso do araguaia
# 'coord'
# Processing Record 32 of Set 11 | lebanon
# Processing Record 33 of Set 11 | xuddur
# Processing Record 34 of Set 11 | nouakchott
# Processing Record 35 of Set 11 | ashqelon
# Processing Record 36 of Set 11 | songjianghe
# Processing Record 37 of Set 11 | flinders
# Processing Record 38 of Set 11 | dawei
# Processing Record 39 of Set 11 | obama
# Processing Record 40 of Set 11 | viana
# Processing Record 41 of Set 11 | bako
# Processing Record 42 of Set 11 | dubti
# Processing Record 43 of Set 11 | diamantino
# Processing Record 44 of Set 11 | bocaranga
# 'coord'
# Processing Record 45 of Set 11 | jega
# Processing Record 46 of Set 11 | kalga
# Processing Record 47 of Set 11 | santa vitoria do palmar
# Processing Record 48 of Set 11 | addi ugri
# 'coord'
# Processing Record 49 of Set 11 | praia
# Processing Record 0 of Set 12 | diplo
# Processing Record 1 of Set 12 | urdoma
# Processing Record 2 of Set 12 | marathopolis
# 'coord'
# Processing Record 3 of Set 12 | griffith
# Processing Record 4 of Set 12 | ailigandi
# Processing Record 5 of Set 12 | aqtobe
# Processing Record 6 of Set 12 | bacuit
# 'coord'
# Processing Record 7 of Set 12 | bubaque
# Processing Record 8 of Set 12 | saquena
# Processing Record 9 of Set 12 | mikhaylovka
# Processing Record 10 of Set 12 | mwanza
# Processing Record 11 of Set 12 | nishihara
# Processing Record 12 of Set 12 | tiarei
# Processing Record 13 of Set 12 | annemasse
# Processing Record 14 of Set 12 | ranot
# Processing Record 15 of Set 12 | santiago del estero
# Processing Record 16 of Set 12 | kavaratti
# Processing Record 17 of Set 12 | bhanpura
# Processing Record 18 of Set 12 | mahon
# Processing Record 19 of Set 12 | acapulco
# Processing Record 20 of Set 12 | obo
# Processing Record 21 of Set 12 | taksimo
# Processing Record 22 of Set 12 | puerto del rosario
# Processing Record 23 of Set 12 | kandry
# Processing Record 24 of Set 12 | sabha
# Processing Record 25 of Set 12 | lang suan
# Processing Record 26 of Set 12 | arica
# Processing Record 27 of Set 12 | tawkar
# 'coord'
# Processing Record 28 of Set 12 | egvekinot
# Processing Record 29 of Set 12 | forssa
# Processing Record 30 of Set 12 | boda
# Processing Record 31 of Set 12 | dzhebariki-khaya
# Processing Record 32 of Set 12 | bitung
# Processing Record 33 of Set 12 | ngaoundere
# Processing Record 34 of Set 12 | nome
# Processing Record 35 of Set 12 | westport
# Processing Record 36 of Set 12 | muravlenko
# Processing Record 37 of Set 12 | ponta delgada
# Processing Record 38 of Set 12 | mae sai
# Processing Record 39 of Set 12 | newport
# Processing Record 40 of Set 12 | tiznit
# Processing Record 41 of Set 12 | zhanakorgan
# Processing Record 42 of Set 12 | villa vazquez
# 'coord'
# Processing Record 43 of Set 12 | linjiang
# Processing Record 44 of Set 12 | sharjah
# Processing Record 45 of Set 12 | la paz
# Processing Record 46 of Set 12 | verkhoyansk
# Processing Record 47 of Set 12 | miyazu
# Processing Record 48 of Set 12 | kovernino
# Processing Record 49 of Set 12 | sierra vista
# Processing Record 0 of Set 13 | gao
# Processing Record 1 of Set 13 | quesnel
# Processing Record 2 of Set 13 | omsukchan
# Processing Record 3 of Set 13 | homer
# Processing Record 4 of Set 13 | sohag
# Processing Record 5 of Set 13 | pokhara
# Processing Record 6 of Set 13 | bwanga
# Processing Record 7 of Set 13 | mitsamiouli
# Processing Record 8 of Set 13 | kazminskoye
# 'coord'
# Processing Record 9 of Set 13 | gamboula
# Processing Record 10 of Set 13 | champerico
# Processing Record 11 of Set 13 | umzimvubu
# 'coord'
# Processing Record 12 of Set 13 | brufut
# Processing Record 13 of Set 13 | meulaboh
# Processing Record 14 of Set 13 | talas
# Processing Record 15 of Set 13 | nanakuli
# Processing Record 16 of Set 13 | muswellbrook
# Processing Record 17 of Set 13 | bayan
# Processing Record 18 of Set 13 | aswan
# Processing Record 19 of Set 13 | awbari
# Processing Record 20 of Set 13 | reconquista
# Processing Record 21 of Set 13 | kedougou
# Processing Record 22 of Set 13 | belize
# Processing Record 23 of Set 13 | valparaiso
# Processing Record 24 of Set 13 | paamiut
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   punta arenas -53.1500  -70.9167      7.06        61          75
# 1  leningradskiy  69.3833  178.4167    -21.95        92          43
# 2          vaini -21.2000 -175.2000     28.09        89          40
# 3         bethel  41.3712  -73.4140     19.93        74         100
# 4     caluquembe -13.7833   14.6833     16.67        89         100
#
#    Wind Speed Country        Date
# 0        6.69      CL  1680823395
# 1        1.91      RU  1680823395
# 2        6.69      TO  1680823396
# 3        4.63      US  1680823400
# 4        0.55      AO  1680823401

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   punta arenas -53.1500  -70.9167      7.06        61          75
# 1  leningradskiy  69.3833  178.4167    -21.95        92          43
# 2          vaini -21.2000 -175.2000     28.09        89          40
# 3         bethel  41.3712  -73.4140     19.93        74         100
# 4     caluquembe -13.7833   14.6833     16.67        89         100
#
#    Wind Speed Country        Date
# 0        6.69      CL  1680823395
# 1        1.91      RU  1680823395
# 2        6.69      TO  1680823396
# 3        4.63      US  1680823400
# 4        0.55      AO  1680823401

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         punta arenas -53.1500  -70.9167      7.06        61          75
# 1        leningradskiy  69.3833  178.4167    -21.95        92          43
# 2                vaini -21.2000 -175.2000     28.09        89          40
# 3               bethel  41.3712  -73.4140     19.93        74         100
# 4           caluquembe -13.7833   14.6833     16.67        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      CL  1680823395
# 1              1.91      RU  1680823395
# 2              6.69      TO  1680823396
# 3              4.63      US  1680823400
# 4              0.55      AO  1680823401

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
y_value= city_data_df['Max Temp']
x_value = city_data_df['Lat']

#Plot scatter for values
plt.scatter(x_value,y_value, s=50, c='red', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Incorporate the other graph properties
plt.title('Latitude vs Max Temp')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_value, y_value)

# Get regression values
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -0.28x +19.35

# %%
# Create Plot
plt.scatter(x_value,y_value,s=50, c='red', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)
plt.plot(x_value,regress_values,"b-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('Latitude vs Temperature')
x_pos, y_pos =-25,-25
plt.annotate(line_eq,(20,15),(x_pos,y_pos),fontsize=15,color="blue")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.47158411959205

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
Y_value = city_data_df['Humidity']
X_value= city_data_df['Lat']

plt.scatter(X_value,Y_value,s=50, c='blue', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Incorporate the other graph properties
plt.title('Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humiditity')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Perform a linear regression on humidity vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(X_value, Y_value)

# Get regression values
regress_values = X_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = 0.01x +71.87

# %%
#annotate line of regression onto scatter plot
plt.scatter(X_value,Y_value,s=50, c='blue', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)
plt.plot(X_value,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Latitude vs Humidity")

plt.annotate(line_eq,(-50,10),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0002743129964930827

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
Y_cloudiness= city_data_df['Cloudiness']

plt.scatter(X_value,Y_cloudiness,s=50, c='white', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Incorporate the other graph properties
plt.title('Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Max Cloudiness')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(X_value, Y_cloudiness)

# Get regression values
regress_values = X_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -0.02x +58.46

# %%
#Calculate trend line 
plt.scatter(X_value,Y_cloudiness,s=50, c='white', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

plt.title('Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Max Cloudiness')

plt.plot(X_value,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Latitude vs Cloudiness")


plt.annotate(line_eq,(-50,10),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0001908731249802735

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
Y_wind= city_data_df['Wind Speed']

plt.scatter(X_value,Y_wind,s=50, c='cyan', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Incorporate the other graph properties
plt.title('Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(X_value, Y_wind)

# Get regression values
regress_values = X_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = 0.01x +3.29

# %%
#Calculate trend line 
plt.scatter(X_value, Y_wind,s=50, c='cyan', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

plt.title('Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.plot(X_value,regress_values,"r-")


plt.annotate(line_eq,(-50,12),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

#Show plot
plt.show()
# Out:
# The r-value is: 0.011130942537861482

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#as above for each model

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df =city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         leningradskiy  69.3833  178.4167    -21.95        92          43
# 3                bethel  41.3712  -73.4140     19.93        74         100
# 6          beringovskiy  63.0500  179.3167    -11.06        90         100
# 7        cabo san lucas  22.8909 -109.9124     25.34        41           0
# 8                albany  42.6001  -73.9662     11.95        85          99
#
#          Wind Speed Country        Date
# City_ID
# 1              1.91      RU  1680823395
# 3              4.63      US  1680823400
# 6              5.17      RU  1680823403
# 7              5.14      MX  1680823404
# 8              4.52      US  1680823405

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df= city_data_df[city_data_df['Lat'] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        punta arenas -53.1500  -70.9167      7.06        61          75
# 2               vaini -21.2000 -175.2000     28.09        89          40
# 4          caluquembe -13.7833   14.6833     16.67        89         100
# 5          boa viagem  -5.1275  -39.7322     22.26        94          98
# 13         codrington -38.2667  141.9667     14.68        88         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      CL  1680823395
# 2              6.69      TO  1680823396
# 4              0.55      AO  1680823401
# 5              1.00      BR  1680823402
# 13             3.26      AU  1680823409

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Build the scatter plots for temperature vs latitude 
X_lat= northern_hemi_df['Lat']
y_temp= northern_hemi_df['Max Temp']

#Calculate linear regression
plt.scatter(X_lat, y_temp,s=50, c='red', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Perform a linear regression on Northern hemisphere Latitude vs temperature 
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(X_lat, y_temp)

# Get regression values
regress_values = X_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.plot(X_lat,regress_values,"b-")

x_pos, y_pos =5,-11
plt.annotate(line_eq,(20,15),(x_pos,y_pos),fontsize=15,color="blue")

# Incorporate the other graph properties
plt.title('Northern Hemisphere Temperature(C) vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')

# Show plot
plt.show()
# Out:
# y = -0.64x +34.53

# %%
# Linear regression on Southern Hemisphere
x_sh_lat= southern_hemi_df['Lat']
Y_sh_temp= southern_hemi_df['Max Temp']

#Calculate linear regression

plt.scatter(x_sh_lat, Y_sh_temp,s=50, c='red', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Perform a linear regression on Southern hemisphere Latitude vs temperature 
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_sh_lat,Y_sh_temp)

# Get regression values
regress_values = x_sh_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.plot(x_sh_lat,regress_values,"b-")

plt.annotate(line_eq,(-50,30),fontsize=15,color="blue")

# Incorporate the other graph properties
plt.title('Southern Hemisphere Temperature(C) vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')

# Show plot
plt.show()
# Out:
# y = 0.23x +26.17

# %% [markdown]
# **Discussion about the linear relationship:
# The northern hemisphere indicates a negative correlation between temperuature and latitude indicating that temperature is
# likely to decrease, the higher the point of latitude. However, this is the opposite for the southern hemisphere which indicates
# the temperature is likely to rise when the latitude approaches 0. This makes rational sense since approaching 0 degrees is
# at the equator, known to be warmer.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Build the scatter plots for humidity vs latitude in northern hemisphere 
x_nh_lat= northern_hemi_df['Lat']
y_nh_humi= northern_hemi_df['Humidity']

#Calculate linear regression
plt.scatter(x_nh_lat, y_nh_humi,s=50, c='blue', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Perform a linear regression on Northern hemisphere Latitude vs humidity 
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_nh_lat, y_nh_humi)

# Get regression values
regress_values = x_nh_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.plot(x_nh_lat,regress_values,"r-")

plt.annotate(line_eq,(45,15),fontsize=15,color="red")

# Incorporate the other graph properties
plt.title('Northern Hemisphere Humidity(%) vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')

# Show plot
plt.show()
# Out:
# y = 0.28x +59.34

# %%
# Southern Hemisphere
# Build the scatter plots for humidity vs latitude in southern hemisphere 
sh_lat= southern_hemi_df['Lat']
sh_humi= southern_hemi_df['Humidity']

#Calculate linear regression
plt.scatter(sh_lat, sh_humi,s=50, c='blue', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Perform a linear regression on Northern hemisphere Latitude vs humidity 
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(sh_lat,sh_humi)

# Get regression values
regress_values = sh_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(sh_lat,regress_values,"r-")
print(line_eq)

#line annotation 
plt.annotate(line_eq,(-20,30),fontsize=15,color="red")

# Incorporate the other graph properties
plt.title('Southern Hemisphere Humidity(%) vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')

# Show plot
plt.show()
# Out:
# y = 0.51x +88.52

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is a positive correlation between humidity and latitude in both hemispheres. Both graphs show that the humidity increases,
# the greater the latitude is. Therefore humidity is likely to be lowest at the lowest poinst of latitude and highest at the higher points of latitude. However, this relationship is stronger in the southern hemisphere through the steeper slope of the graph.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_lat= northern_hemi_df['Lat']
nh_cloud= northern_hemi_df['Cloudiness']

#Calculate linear regression
plt.scatter(nh_lat, nh_cloud,s=50, c='white', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)


# Perform a linear regression on Northern hemisphere Latitude vs temperature 
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(nh_lat, nh_cloud)

# Get regression values
regress_values = nh_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(nh_lat, regress_values, 'r');
print(line_eq)

plt.plot(nh_lat,regress_values,"r-")

plt.annotate(line_eq,(50,65),fontsize=15,color="red")

# Incorporate the other graph properties
plt.title('Northern Hemisphere Cloudiness(%) vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')

# Show plot
plt.show()
# Out:
# y = 0.17x +49.05

# %%
# Southern Hemisphere
# Build the scatter plots for humidity vs latitude in southern hemisphere 
sh_lat= southern_hemi_df['Lat']
sh_cloud= southern_hemi_df['Cloudiness']

#Calculate linear regression
plt.scatter(sh_lat, sh_cloud,s=50, c='white', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Perform a linear regression on Northern hemisphere Latitude vs humidity 
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(sh_lat,sh_cloud)

# Get regression values
regress_values = sh_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(sh_lat,regress_values,"r-")
print(line_eq)

#line annotation 

plt.annotate(line_eq,(-55,25),fontsize=15,color="red")
plt.plot(sh_lat, regress_values, 'r');

# Incorporate the other graph properties
plt.title('Southern Hemisphere Cloudiness(%) vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')

# Show plot
plt.show()
# Out:
# y = 0.73x +79.84

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Both graphs indicate a positive correlation between cloudiness and latitude. However the slope being steeper in the southern
# in the southern hemisphere shows a greater correlation for the southern hemisphere over the northern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_lat= northern_hemi_df['Lat']
nh_ws= northern_hemi_df['Wind Speed']

#Calculate linear regression
plt.scatter(nh_lat, nh_ws,s=50, c='cyan', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Perform a linear regression on Northern hemisphere Latitude vs humidity 
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(nh_lat,nh_ws)

# Get regression values
regress_values = nh_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(nh_lat,regress_values,"r-")
print(line_eq)

#line annotation 

plt.annotate(line_eq,(5,12),fontsize=15,color="red")

# Incorporate the other graph properties
plt.title('Northern Hemisphere Wind Speed(m/s) vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')

# Show plot
plt.show()
# Out:
# y = 0.01x +3.31

# %%
# Southern Hemisphere
# Build the scatter plots for humidity vs latitude in southern hemisphere 
sh_lat= southern_hemi_df['Lat']
sh_ws= southern_hemi_df['Wind Speed']

#Calculate linear regression

plt.scatter(sh_lat, sh_ws,s=50, c='cyan', marker ='o',edgecolor='black', linewidth=1, alpha =0.75)

# Perform a linear regression on Northern hemisphere Latitude vs humidity 
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(sh_lat,sh_ws)

# Get regression values
regress_values = sh_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(sh_lat,regress_values,"r-")
print(line_eq)

#line annotation 
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.plot(sh_lat, regress_values, 'r');

# Incorporate the other graph properties
plt.title('Southern Hemisphere Wind Speed(m/s) vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')

# Show plot
plt.show()
# Out:
# y = -0.04x +2.08

# %% [markdown]
# **Discussion about the linear relationship:**
#
# These graphs show different correlations between wind speed and latitude. The northern hemisphere shows only a very slight
# positive relationship while the southern hemisphere shows a negative relationship. Wind speed is likely to be higher a lower
# points of latitude and lower the closer to 0 the latitude gets.
